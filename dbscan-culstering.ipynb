# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
X, y = make_moons(n_samples=100, noise=0.1, random_state=42)
X = pd.DataFrame(X, columns=['x1', 'x2'])

# %%
X.head()
# Out:
#          x1        x2
# 0  1.582023 -0.445815
# 1  0.066045  0.439207
# 2  0.736631 -0.398963
# 3 -1.056928  0.242456
# 4 -0.802162  0.202718

# %%
plt.scatter(X['x1'], X['x2'], s=15, color="blue")

# %%
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 1.2127183 , -1.39758462],
#        [-0.49392533,  0.39023163],
#        [ 0.26100078, -1.30294095],
#        [-1.758136  , -0.00722261],
#        [-1.47132704, -0.08749539],
#        [-1.36353614,  1.05999874],
#        [-0.33705672,  1.15694416],
#        [ 0.98309091, -1.39913097],
#        [ 0.38659399,  0.85993117],
#        [ 0.4697172 , -0.66747667],
#        [-0.12953039,  1.15513378],
#        [-0.94013722,  1.37586684],
#        [ 0.74586875, -1.70478506],
#        [-1.2399088 ,  1.31609422],
#        [ 1.5992354 , -0.12694895],
#        [ 0.70337891,  0.18180053],
#        [ 0.69858542, -1.31658191],
#        [ 0.66845838, -1.54501725],
#        [ 0.07353272,  0.86210282],
#        [-0.91559887,  1.30782463],
#        [-0.59806491, -0.19618464],
#        [ 1.4962225 , -0.84810261],
#        [-0.58069524,  1.24884498],
#        [-1.68053773,  0.27713121],
#        [ 0.02122148, -0.78810061],
#        [-0.04761917,  1.34462506],
#        [-1.58675518,  0.50123233],
#        [ 1.69642636, -0.16775057],
#        [ 0.30060895,  0.57543285],
#        [ 0.28257875, -1.64729866],
#        [ 0.41127715,  1.01548608],
#        [-1.73453786, -0.2556827 ],
#        [ 1.39865998, -1.35448528],
#        [-0.78073092,  1.8713092 ],
#        [ 1.82220737, -0.63690981],
#        [ 0.4142879 ,  0.17361166],
#        [-0.17491046, -1.34941097],
#        [-0.10203425, -0.8606983 ],
#        [-1.27529483,  1.12618259],
#        [ 0.07300138,  1.3402434 ],
#        [-1.69088434, -0.73882404],
#        [-1.1234501 ,  1.24697541],
#        [ 0.32253825,  0.24164681],
#        [ 1.74635946,  0.12294718],
#        [-0.8290389 ,  1.44265496],
#        [-0.19562566,  1.52341856],
#        [ 1.15378909, -1.32088798],
#        [-0.47273372,  1.69845674],
#        [-0.22805142, -1.18389255],
#        [ 0.07288301,  1.14815482],
#        [-0.72476065,  1.5460743 ],
#        [ 0.64936534, -0.08005679],
#        [-0.11526844,  1.12297615],
#        [-1.33361045,  0.90775932],
#        [ 0.38048857,  0.70948373],
#        [ 0.90414188, -1.09508505],
#        [ 0.53903806,  0.22783629],
#        [-0.16051031, -1.45712381],
#        [-1.30817288,  0.9952437 ],
#        [ 1.30996591, -0.70030229],
#        [-0.33479205, -0.39341668],
#        [ 1.57520236,  0.73624176],
#        [-0.46005757,  0.61900057],
#        [-1.76021349,  0.40659071],
#        [-0.53271489,  0.52501267],
#        [ 0.13928449, -1.28396927],
#        [-1.8912791 , -0.28202006],
#        [ 0.25540444, -1.09739038],
#        [-0.34172448, -0.69470544],
#        [ 1.98742952,  0.24841524],
#        [ 0.87650257, -1.38504629],
#        [-1.48085051,  0.42380524],
#        [-0.35517506, -0.87100154],
#        [-1.65386389, -0.3573482 ],
#        [ 1.6564708 ,  0.28760457],
#        [-0.52539209, -0.52778046],
#        [ 0.33261515, -1.560147  ],
#        [-0.96556744,  1.22624333],
#        [ 1.69741205, -0.34171582],
#        [-0.5329929 , -0.74064691],
#        [-0.31481068, -1.22136721],
#        [ 1.25220019, -0.7844195 ],
#        [-1.45205617,  0.56657097],
#        [-0.81464947,  1.14951981],
#        [ 0.42197216, -0.26758273],
#        [-0.57764448,  0.11590032],
#        [-0.31007463,  1.38972607],
#        [ 0.76097094, -0.37519867],
#        [-0.56300637,  1.42182265],
#        [ 1.31972294, -0.7719725 ],
#        [ 1.31419736, -0.39219088],
#        [ 0.4604747 , -1.34908065],
#        [ 1.30898683, -0.87760325],
#        [ 1.03414296, -1.18948042],
#        [-0.06066181,  1.29025161],
#        [-0.35678188, -0.79341379],
#        [ 0.48631943, -1.54405508],
#        [ 0.05114526,  0.96554304],
#        [ 1.55649947, -0.52373706],
#        [-0.60744297,  0.41536642]])

# %%
dbscan = DBSCAN(eps=0.3)

# %%
dbscan.fit(X_scaled)
# Out:
# DBSCAN(eps=0.3)

# %%
dbscan.labels_
# Out:
# array([ 0,  1,  0,  4, -1,  2,  2,  0, -1, -1,  2,  2,  0,  2,  6, -1,  0,
#         0,  2,  2, -1,  3,  2,  4,  5,  2,  4,  6, -1,  0, -1, -1,  0, -1,
#        -1, -1, -1,  5,  2,  2, -1,  2, -1,  6,  2,  2,  0,  2, -1,  2,  2,
#        -1,  2,  2, -1,  0, -1, -1,  2,  3, -1, -1,  1,  4,  1,  0, -1,  0,
#         5,  6,  0,  4,  5, -1,  6,  5,  0,  2, -1,  5, -1,  3,  4,  2, -1,
#         1,  2, -1,  2,  3, -1,  0,  3,  0,  2,  5,  0,  2, -1,  1])

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=dbscan.labels_)
